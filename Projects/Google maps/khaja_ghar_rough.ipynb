# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.google.com/maps/search/newari+khaja+ghar/@27.6820179,85.2764369,11z/data=!3m1!4b1!4m2!2m1!6e5?entry=ttu&g_ep=EgoyMDI0MTIxMS4wIKXMDSoASAFQAw%3D%3D'

# %%
response = requests.get(url)

# %%
data = BeautifulSoup(response.text, 'html.parser')

# %%
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Place" lang="ne">
#  <head>
#   <link as="script" href="/maps/_/js/k=maps.m.ne.bSWEFjgnyH0.es5.O/m=sc2,per,mo,lp,ep,ti,ds,stx,dwi,enr,pwd,dw,plm,log,b/am=YACQ5IAU/rt=j/d=1/rs=ACT90oGPIbt9MBaaJzWzDt1SInPTS3NkzA?wli=m.DUKneoDoDjA.loadSv.O%3A%3B" nonce="1z9nRE2hLhQtbuW12g3q7g" rel="preload" type="application/javascript"/>
#   <link href="/maps/preview/opensearch.xml?hl=ne" rel="search" title="Google नक्सा" type="application/opensearchdescription+xml"/>
#   <title>
#    Google नक्सा
#   </title>
#   <meta content="स्थानिय ब्यापार खोज्नुहोस्, नक्सा हेर्नुहोस् र Google नक्सामा ड्राईभिन्ग दिशाहरु पाउनुहोस्।" name="Description"/>
#   <meta content="Newari khaja ghar" itemprop="name"/>
#   <meta content="Newari khaja ghar" property="og:title"/>
# ...

# %%
#find all the div tags
data.find_all('div')
# Out:
# [<div id="XvQR9b"> <div class="wSgKnf"> <div> When you have eliminated the <strong>JavaScript</strong>, whatever remains must be an empty page. </div> <a class="hl4GXb" href="https://support.google.com/maps/?hl=ne&amp;authuser=0&amp;p=no_javascript" target="_blank">Google नक्सा हेर्न JavaScript अन गर्नुहोस्</a> </div> </div>,
#  <div class="wSgKnf"> <div> When you have eliminated the <strong>JavaScript</strong>, whatever remains must be an empty page. </div> <a class="hl4GXb" href="https://support.google.com/maps/?hl=ne&amp;authuser=0&amp;p=no_javascript" target="_blank">Google नक्सा हेर्न JavaScript अन गर्नुहोस्</a> </div>,
#  <div> When you have eliminated the <strong>JavaScript</strong>, whatever remains must be an empty page. </div>]

# %%
data.find_all('div', class_='qBF1Pd fontHeadlineSmall ')
# Out:
# []

# %%
data.find_all('a', class_='hfpxzc')
# Out:
# []

# %%
data.find_all('input', class_='fontBodyMedium searchboxinput xiQnY ')
# Out:
# []
